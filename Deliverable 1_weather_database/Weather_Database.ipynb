# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

import requests
from datetime import datetime
import timeit

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(57.407728419576415, -77.73604349110943), (-37.742047743303566, -107.61623287080278), (-72.74775176484263, 177.71802266510417), (-17.314905706501875, 159.5083828646998), (-23.875394278714765, 105.30252850564779), (2.4196217972974097, 68.67390427583757), (73.44194154369526, 26.280595258335694), (-55.33328273546185, -132.10932538552336), (-33.80071138471718, 109.88731508389816), (79.56342506714924, -67.3061290600413), (-81.7386814043229, 158.6175101037398), (-47.47042408547923, -47.71682692191382), (-13.836949551278437, -145.1657441393482), (6.970226653769629, 101.0131373913033), (-49.83073843181798, 157.81360382373293), (33.50527700326876, 1.7803418895439052), (-33.52786007560351, 116.38931893218432), (72.66628741298612, 159.59004018098506), (0.2624782587406145, 49.68541830832294), (68.04592257638274, -117.18818266356956), (-16.25585724456863, 164.1321685888327), (-57.95843180658189, -143.72882075704558), (66.09125120815241, -154.6581924422147), (-55.886613311857694, -42.03880894571844), (-55.97872156285536, -70.70880324063955), (8.697084848987913, -42.31649348419634), (-51.642312737761074, 43.13803639092251), (65.00602036594208, 162.36335474880576), (52.24515156090206, -56.63303211094521), (67.19020051509577, -133.13792692839388), (-78.8596111839382, -44.07268913219238), (74.00212411400088, -119.34850014857949), (-30.65491061947425, 46.33484721288394), (-74.19190037552303, 48.061267164152696), (-72.59831335859916, -14.570730488859198), (13.39305003265163, 172.89388288775353), (-88.62339762846183, -76.30870679649551), (-38.48008994731271, 162.9003727331658), (41.48307134215881, -179.00354300739707), (-4.7834275536718, -69.39679579577083), (-7.020018956294464, 128.27549175555606), (-49.52617117599769, 97.86495625814104), (32.0039916838321, -7.604801433960205), (71.21245832381959, -178.26913323443426), (49.26289656052768, 94.7918878836885), (28.986543269593696, 116.24786258162595), (-65.57659952874153, -178.83562737686594), (-6.482429285026811, 166.26400058584375), (-89.25617168303651, -143.87185253021178), (15.464389986537313, 107.93083872805971), (-2.2543532662223953, 73.61028993769983), (-16.964510620513693, -147.94308797808267), (-34.384441840895086, -34.64549473842774), (-74.82755728330434, -159.7311551617139), (79.5350198714359, -124.247990796383), (-24.611439752706588, 94.22146072240815), (78.41309140454959, 54.14568108845063), (-66.56598267856145, -178.87075120804388), (83.70480687714635, 152.3032989948063), (-25.124431884308578, -71.40303318565932), (48.17575626322184, -111.28895058279701), (82.90221932087258, -157.7683882588611), (-58.013089401199124, 19.785727551732066), (-57.364004089898025, 148.48394293085647), (16.864595349148445, 109.04020107518062), (16.676301209491385, -115.7721798413208), (-67.38724652870651, 13.509354822270325), (70.76867789593533, 50.567767840700924), (87.91182166510683, -40.5782282224246), (-47.421195808227345, 143.84114991299992), (-3.047524702572474, 127.09153189230483), (86.65240022838711, -154.16149638646823), (-24.304584671018148, -19.319200603172646), (-80.26314446245698, 116.02778209899367), (82.28458681058768, -79.14668092613323), (88.13188379189728, 35.36035472616268), (-75.44610650085649, 32.24475644999393), (35.576257520710584, -80.32390783771959), (29.766877852089692, 54.24093977622758), (64.58817885528956, -105.46154650249943), (-15.88305090698293, 115.07091326854311), (3.4675651574347484, -127.51174013611225), (-76.45064794518717, -17.009249888236212), (82.39812141078121, 176.56807004541963), (25.82461370729473, 4.769548770414616), (-23.11440937427072, 139.74791403801441), (82.43228840776308, 29.51779631628611), (48.1796752075135, 26.67305770999826), (-40.99605996867647, -99.54073474623604), (34.93935568893019, 166.97663785293696), (33.642914547553545, 21.88479497618735), (-71.48901946461358, 79.90471840135189), (-12.25973335893761, -158.70677210486272), (3.631972584639712, -74.44462588778521), (-13.816921210525507, 176.66593180419972), (-24.760902305058806, -167.01756620327578 ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
#Once we get to 50, we tell the program to pause for 60 seconds using the time.sleep(60) command. 
#The OpenWeatherMap API only allows 60 calls for per minute on their free tier, 
#so pausing our program for one minute after each set of 50 will prevent time-out errors. 
        #time.sleep(60)
#We can also retrieve the city from the cities list and add it to the city_url by using indexing,    
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.Module 6.2.6
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
            # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | poum
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | kudahuvadhoo
# Processing Record 7 of Set 1 | honningsvag
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | narsaq
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | tiarei
# Processing Record 13 of Set 1 | nong chik
# Processing Record 14 of Set 1 | tuatapere
# Processing Record 15 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 1 | collie
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | mogadishu
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | luganville
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | salinopolis
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | saint anthony
# Processing Record 27 of Set 1 | inuvik
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | te anau
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | jutai
# Processing Record 36 of Set 1 | ambon
# Processing Record 37 of Set 1 | marrakesh
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | erzin
# Processing Record 40 of Set 1 | nanchang
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | lata
# Processing Record 43 of Set 1 | tam ky
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | tautira
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | taltal
# Processing Record 1 of Set 2 | great falls
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | da nang
# Processing Record 5 of Set 2 | cabo san lucas
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | ilulissat
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | vardo
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | salisbury
# Processing Record 15 of Set 2 | shahr-e babak
# Processing Record 16 of Set 2 | karratha
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | leningradskiy
# Processing Record 19 of Set 2 | adrar
# Processing Record 20 of Set 2 | mount isa
# Processing Record 21 of Set 2 | mehamn
# Processing Record 22 of Set 2 | paltinis
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | severo-kurilsk
# Processing Record 25 of Set 2 | darnah
# Processing Record 26 of Set 2 | faanui
# Processing Record 27 of Set 2 | villarrica
# Processing Record 28 of Set 2 | asau
# Processing Record 29 of Set 2 | alofi
# Processing Record 30 of Set 2 | nanyamba
# Processing Record 31 of Set 2 | colac
# Processing Record 32 of Set 2 | laguna
# Processing Record 33 of Set 2 | airai
# Processing Record 34 of Set 2 | weiser
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | clyde river
# Processing Record 37 of Set 2 | srednekolymsk
# Processing Record 38 of Set 2 | martapura
# Processing Record 39 of Set 2 | husavik
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | puerto escondido
# Processing Record 43 of Set 2 | labytnangi
# Processing Record 44 of Set 2 | saskylakh
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | vestmannaeyjar
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | viedma
# Processing Record 50 of Set 2 | takoradi
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 2 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | capinzal
# Processing Record 5 of Set 3 | qurbus
# Processing Record 6 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 3 | bambous virieux
# Processing Record 8 of Set 3 | kapaa
# Processing Record 9 of Set 3 | kushima
# Processing Record 10 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 3 | brae
# Processing Record 12 of Set 3 | bathsheba
# Processing Record 13 of Set 3 | kedougou
# Processing Record 14 of Set 3 | nabire
# Processing Record 15 of Set 3 | karasburg
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | port blair
# Processing Record 19 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 3 | galesong
# Processing Record 21 of Set 3 | hamilton
# Processing Record 22 of Set 3 | jubayl
# City not found. Skipping...
# Processing Record 23 of Set 3 | luderitz
# Processing Record 24 of Set 3 | smirnykh
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | pisco
# Processing Record 27 of Set 3 | sorong
# Processing Record 28 of Set 3 | tateyama
# Processing Record 29 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | haines junction
# Processing Record 32 of Set 3 | tiksi
# Processing Record 33 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 34 of Set 3 | bonthe
# Processing Record 35 of Set 3 | beyneu
# Processing Record 36 of Set 3 | makushino
# Processing Record 37 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3 | naze
# Processing Record 39 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 3 | filingue
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | moerai
# Processing Record 43 of Set 3 | gurupi
# Processing Record 44 of Set 3 | binga
# Processing Record 45 of Set 3 | kahului
# Processing Record 46 of Set 3 | atlantis
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | mandalgovi
# Processing Record 49 of Set 3 | vostok
# Processing Record 50 of Set 3 | xai-xai
# Processing Record 1 of Set 4 | tres picos
# Processing Record 2 of Set 4 | seminole
# Processing Record 3 of Set 4 | neiafu
# Processing Record 4 of Set 4 | uvalde
# Processing Record 5 of Set 4 | oksfjord
# Processing Record 6 of Set 4 | calvinia
# Processing Record 7 of Set 4 | bismarck
# Processing Record 8 of Set 4 | portland
# Processing Record 9 of Set 4 | hervey bay
# Processing Record 10 of Set 4 | prattville
# Processing Record 11 of Set 4 | tukrah
# Processing Record 12 of Set 4 | birin
# Processing Record 13 of Set 4 | san cristobal
# Processing Record 14 of Set 4 | nalut
# Processing Record 15 of Set 4 | petatlan
# Processing Record 16 of Set 4 | batagay-alyta
# Processing Record 17 of Set 4 | tarnogskiy gorodok
# Processing Record 18 of Set 4 | burnie
# Processing Record 19 of Set 4 | mwinilunga
# Processing Record 20 of Set 4 | ulaangom
# Processing Record 21 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | kijang
# Processing Record 24 of Set 4 | agadez
# Processing Record 25 of Set 4 | oskemen
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | kanye
# Processing Record 28 of Set 4 | sabang
# Processing Record 29 of Set 4 | minab
# Processing Record 30 of Set 4 | college
# Processing Record 31 of Set 4 | bridlington
# Processing Record 32 of Set 4 | jacareacanga
# Processing Record 33 of Set 4 | hirado
# Processing Record 34 of Set 4 | hilo
# Processing Record 35 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 4 | koregaon
# Processing Record 37 of Set 4 | ramanathapuram
# Processing Record 38 of Set 4 | pacific grove
# Processing Record 39 of Set 4 | nouadhibou
# Processing Record 40 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 4 | praia da vitoria
# Processing Record 42 of Set 4 | conde
# Processing Record 43 of Set 4 | kalmunai
# Processing Record 44 of Set 4 | constitucion
# Processing Record 45 of Set 4 | abha
# Processing Record 46 of Set 4 | guerrero negro
# Processing Record 47 of Set 4 | tecoanapa
# Processing Record 48 of Set 4 | mahebourg
# Processing Record 49 of Set 4 | saint-pierre
# Processing Record 50 of Set 4 | iaciara
# Processing Record 1 of Set 5 | coahuayana
# Processing Record 2 of Set 5 | excelsior springs
# Processing Record 3 of Set 5 | cardston
# Processing Record 4 of Set 5 | almaznyy
# Processing Record 5 of Set 5 | ordynskoye
# Processing Record 6 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 5 | nikolskoye
# Processing Record 8 of Set 5 | usinsk
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | luwuk
# Processing Record 11 of Set 5 | bilma
# Processing Record 12 of Set 5 | havelock
# Processing Record 13 of Set 5 | quchan
# Processing Record 14 of Set 5 | zhigansk
# Processing Record 15 of Set 5 | sambava
# Processing Record 16 of Set 5 | olafsvik
# Processing Record 17 of Set 5 | mildura
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | lorengau
# Processing Record 20 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 5 | coquimbo
# Processing Record 23 of Set 5 | drayton valley
# Processing Record 24 of Set 5 | victoria point
# Processing Record 25 of Set 5 | seydi
# Processing Record 26 of Set 5 | sinnamary
# Processing Record 27 of Set 5 | oranjestad
# Processing Record 28 of Set 5 | batemans bay
# Processing Record 29 of Set 5 | salalah
# Processing Record 30 of Set 5 | mount gambier
# Processing Record 31 of Set 5 | puerto narino
# Processing Record 32 of Set 5 | lokosovo
# Processing Record 33 of Set 5 | broome
# Processing Record 34 of Set 5 | namibe
# Processing Record 35 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 5 | karimganj
# Processing Record 37 of Set 5 | saldanha
# Processing Record 38 of Set 5 | prince rupert
# Processing Record 39 of Set 5 | cap malheureux
# Processing Record 40 of Set 5 | avera
# Processing Record 41 of Set 5 | georgetown
# Processing Record 42 of Set 5 | magrath
# Processing Record 43 of Set 5 | arvika
# Processing Record 44 of Set 5 | vila
# Processing Record 45 of Set 5 | tarakan
# Processing Record 46 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 47 of Set 5 | alice springs
# Processing Record 48 of Set 5 | kupang
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | praia
# Processing Record 1 of Set 6 | komsomolskiy
# Processing Record 2 of Set 6 | forrest city
# Processing Record 3 of Set 6 | kannauj
# Processing Record 4 of Set 6 | pemangkat
# Processing Record 5 of Set 6 | illela
# Processing Record 6 of Set 6 | la ronge
# Processing Record 7 of Set 6 | baykit
# Processing Record 8 of Set 6 | palana
# Processing Record 9 of Set 6 | zuwarah
# Processing Record 10 of Set 6 | new waterford
# Processing Record 11 of Set 6 | ligayan
# Processing Record 12 of Set 6 | longyearbyen
# Processing Record 13 of Set 6 | dudinka
# Processing Record 14 of Set 6 | loandjili
# Processing Record 15 of Set 6 | shache
# Processing Record 16 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 17 of Set 6 | kyaikkami
# Processing Record 18 of Set 6 | touros
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | saint-augustin
# Processing Record 21 of Set 6 | pangnirtung
# Processing Record 22 of Set 6 | verkh-chebula
# Processing Record 23 of Set 6 | westport
# Processing Record 24 of Set 6 | termoli
# Processing Record 25 of Set 6 | sioux lookout
# Processing Record 26 of Set 6 | penhold
# Processing Record 27 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 6 | dikson
# Processing Record 29 of Set 6 | tasiilaq
# Processing Record 30 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 6 | torbay
# Processing Record 32 of Set 6 | diamantino
# Processing Record 33 of Set 6 | vila velha
# Processing Record 34 of Set 6 | tunxi
# City not found. Skipping...
# Processing Record 35 of Set 6 | presidente medici
# Processing Record 36 of Set 6 | goderich
# Processing Record 37 of Set 6 | eureka
# Processing Record 38 of Set 6 | aklavik
# Processing Record 39 of Set 6 | vaiano
# Processing Record 40 of Set 6 | fortuna
# Processing Record 41 of Set 6 | sun valley
# Processing Record 42 of Set 6 | krasnoselkup
# Processing Record 43 of Set 6 | shingu
# Processing Record 44 of Set 6 | palmer
# Processing Record 45 of Set 6 | kavieng
# Processing Record 46 of Set 6 | gumla
# Processing Record 47 of Set 6 | scottsbluff
# Processing Record 48 of Set 6 | ornskoldsvik
# Processing Record 49 of Set 6 | wiang sa
# Processing Record 50 of Set 6 | verkhnevilyuysk
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | port lincoln
# Processing Record 3 of Set 7 | revda
# Processing Record 4 of Set 7 | burica
# City not found. Skipping...
# Processing Record 5 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 7 | cidreira
# Processing Record 7 of Set 7 | autazes
# Processing Record 8 of Set 7 | vung tau
# Processing Record 9 of Set 7 | channel-port aux basques
# Processing Record 10 of Set 7 | khatanga
# Processing Record 11 of Set 7 | camamu
# Processing Record 12 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 7 | manggar
# Processing Record 14 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 15 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 7 | saint-francois
# Processing Record 17 of Set 7 | nedjo
# Processing Record 18 of Set 7 | tagab
# Processing Record 19 of Set 7 | moctezuma
# Processing Record 20 of Set 7 | azare
# Processing Record 21 of Set 7 | lasa
# Processing Record 22 of Set 7 | phuket
# Processing Record 23 of Set 7 | kamaishi
# Processing Record 24 of Set 7 | zaysan
# Processing Record 25 of Set 7 | tahta
# Processing Record 26 of Set 7 | gorontalo
# Processing Record 27 of Set 7 | qeshm
# Processing Record 28 of Set 7 | sao joao da barra
# Processing Record 29 of Set 7 | businga
# Processing Record 30 of Set 7 | nantucket
# Processing Record 31 of Set 7 | lagoa
# Processing Record 32 of Set 7 | tual
# Processing Record 33 of Set 7 | mudyuga
# City not found. Skipping...
# Processing Record 34 of Set 7 | kuzino
# Processing Record 35 of Set 7 | fort frances
# Processing Record 36 of Set 7 | boueni
# Processing Record 37 of Set 7 | vila franca do campo
# Processing Record 38 of Set 7 | qasigiannguit
# Processing Record 39 of Set 7 | trinidad
# Processing Record 40 of Set 7 | changying
# Processing Record 41 of Set 7 | seoul
# Processing Record 42 of Set 7 | krasnovka
# Processing Record 43 of Set 7 | beira
# Processing Record 44 of Set 7 | high level
# Processing Record 45 of Set 7 | gejiu
# Processing Record 46 of Set 7 | iralaya
# Processing Record 47 of Set 7 | maskinonge
# Processing Record 48 of Set 7 | dori
# Processing Record 49 of Set 7 | teya
# Processing Record 50 of Set 7 | ridgecrest
# Processing Record 1 of Set 8 | nago
# Processing Record 2 of Set 8 | bengkulu
# Processing Record 3 of Set 8 | katobu
# Processing Record 4 of Set 8 | hasaki
# Processing Record 5 of Set 8 | kautokeino
# Processing Record 6 of Set 8 | deggendorf
# Processing Record 7 of Set 8 | nur
# Processing Record 8 of Set 8 | ayorou
# Processing Record 9 of Set 8 | mishan
# Processing Record 10 of Set 8 | novaya malykla
# Processing Record 11 of Set 8 | cockburn town
# Processing Record 12 of Set 8 | san carlos de bariloche
# Processing Record 13 of Set 8 | noumea
# Processing Record 14 of Set 8 | caravelas
# Processing Record 15 of Set 8 | bairiki
# Processing Record 16 of Set 8 | plettenberg bay
# Processing Record 17 of Set 8 | chicama
# Processing Record 18 of Set 8 | loikaw
# Processing Record 19 of Set 8 | kyren
# Processing Record 20 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 8 | granada
# Processing Record 22 of Set 8 | dunedin
# Processing Record 23 of Set 8 | tougue
# Processing Record 24 of Set 8 | netarhat
# Processing Record 25 of Set 8 | datong
# Processing Record 26 of Set 8 | ostrovnoy
# Processing Record 27 of Set 8 | iqaluit
# Processing Record 28 of Set 8 | lienz
# Processing Record 29 of Set 8 | millinocket
# Processing Record 30 of Set 8 | kathmandu
# Processing Record 31 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 32 of Set 8 | fort-shevchenko
# Processing Record 33 of Set 8 | kruisfontein
# Processing Record 34 of Set 8 | stony plain
# Processing Record 35 of Set 8 | sao filipe
# Processing Record 36 of Set 8 | puerto baquerizo moreno
# Processing Record 37 of Set 8 | tucupita
# Processing Record 38 of Set 8 | bosaso
# Processing Record 39 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 40 of Set 8 | mwense
# Processing Record 41 of Set 8 | khilok
# Processing Record 42 of Set 8 | grindavik
# Processing Record 43 of Set 8 | svetlyy
# Processing Record 44 of Set 8 | tass
# Processing Record 45 of Set 8 | labrea
# Processing Record 46 of Set 8 | corinto
# Processing Record 47 of Set 8 | colares
# Processing Record 48 of Set 8 | mae hong son
# Processing Record 49 of Set 8 | nampula
# Processing Record 50 of Set 8 | tura
# Processing Record 1 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 9 | jalgaon
# Processing Record 3 of Set 9 | fare
# Processing Record 4 of Set 9 | koslan
# Processing Record 5 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 9 | payakumbuh
# Processing Record 7 of Set 9 | areka
# Processing Record 8 of Set 9 | itanagar
# Processing Record 9 of Set 9 | lebu
# Processing Record 10 of Set 9 | bac lieu
# Processing Record 11 of Set 9 | lithakia
# Processing Record 12 of Set 9 | nuuk
# Processing Record 13 of Set 9 | marzuq
# Processing Record 14 of Set 9 | ust-tsilma
# Processing Record 15 of Set 9 | broken hill
# Processing Record 16 of Set 9 | fairbanks
# Processing Record 17 of Set 9 | port hedland
# Processing Record 18 of Set 9 | yenagoa
# Processing Record 19 of Set 9 | donskoy
# Processing Record 20 of Set 9 | kichmengskiy gorodok
# Processing Record 21 of Set 9 | ventspils
# Processing Record 22 of Set 9 | plymouth
# Processing Record 23 of Set 9 | aketi
# Processing Record 24 of Set 9 | el corpus
# Processing Record 25 of Set 9 | horodnytsya
# Processing Record 26 of Set 9 | antofagasta
# Processing Record 27 of Set 9 | basoko
# Processing Record 28 of Set 9 | coffs harbour
# Processing Record 29 of Set 9 | thanh hoa
# Processing Record 30 of Set 9 | zhuhai
# Processing Record 31 of Set 9 | nelson bay
# Processing Record 32 of Set 9 | ambilobe
# Processing Record 33 of Set 9 | biak
# Processing Record 34 of Set 9 | vallenar
# Processing Record 35 of Set 9 | ponta do sol
# Processing Record 36 of Set 9 | ucluelet
# Processing Record 37 of Set 9 | dangara
# Processing Record 38 of Set 9 | big bend
# Processing Record 39 of Set 9 | maniitsoq
# Processing Record 40 of Set 9 | marawi
# Processing Record 41 of Set 9 | nishihara
# Processing Record 42 of Set 9 | kolvereid
# Processing Record 43 of Set 9 | pervomayskoye
# Processing Record 44 of Set 9 | banamba
# Processing Record 45 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 46 of Set 9 | bulungu
# Processing Record 47 of Set 9 | timmins
# Processing Record 48 of Set 9 | penzberg
# Processing Record 49 of Set 9 | chateaubelair
# Processing Record 50 of Set 9 | hobyo
# Processing Record 1 of Set 10 | graaff-reinet
# Processing Record 2 of Set 10 | thornbury
# Processing Record 3 of Set 10 | morris
# Processing Record 4 of Set 10 | launceston
# Processing Record 5 of Set 10 | balabac
# Processing Record 6 of Set 10 | brande
# Processing Record 7 of Set 10 | quatre cocos
# Processing Record 8 of Set 10 | shajapur
# Processing Record 9 of Set 10 | mula
# Processing Record 10 of Set 10 | liberal
# Processing Record 11 of Set 10 | linxia
# Processing Record 12 of Set 10 | geraldton
# Processing Record 13 of Set 10 | kushiro
# Processing Record 14 of Set 10 | bubaque
# Processing Record 15 of Set 10 | atasu
# Processing Record 16 of Set 10 | kohlu
# Processing Record 17 of Set 10 | del rio
# Processing Record 18 of Set 10 | poronaysk
# Processing Record 19 of Set 10 | varkaus
# Processing Record 20 of Set 10 | mbini
# Processing Record 21 of Set 10 | tshikapa
# Processing Record 22 of Set 10 | pampa
# Processing Record 23 of Set 10 | daru
# Processing Record 24 of Set 10 | chibombo
# Processing Record 25 of Set 10 | waingapu
# Processing Record 26 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 10 | udachnyy
# Processing Record 28 of Set 10 | shatura
# Processing Record 29 of Set 10 | rabo de peixe
# Processing Record 30 of Set 10 | yakeshi
# Processing Record 31 of Set 10 | edd
# Processing Record 32 of Set 10 | makakilo city
# Processing Record 33 of Set 10 | nouakchott
# Processing Record 34 of Set 10 | chipinge
# Processing Record 35 of Set 10 | souillac
# Processing Record 36 of Set 10 | fort nelson
# Processing Record 37 of Set 10 | cairns
# Processing Record 38 of Set 10 | belfort
# Processing Record 39 of Set 10 | mikhaylovka
# Processing Record 40 of Set 10 | vanimo
# Processing Record 41 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 10 | khani
# Processing Record 43 of Set 10 | rawson
# Processing Record 44 of Set 10 | kabare
# Processing Record 45 of Set 10 | hami
# Processing Record 46 of Set 10 | cheremisinovo
# Processing Record 47 of Set 10 | deputatskiy
# Processing Record 48 of Set 10 | tevaitoa
# Processing Record 49 of Set 10 | ferrol
# Processing Record 50 of Set 10 | meridian
# Processing Record 1 of Set 11 | saryg-sep
# Processing Record 2 of Set 11 | iwanai
# Processing Record 3 of Set 11 | rocha
# Processing Record 4 of Set 11 | algiers
# Processing Record 5 of Set 11 | karymskoye
# Processing Record 6 of Set 11 | leninskoye
# Processing Record 7 of Set 11 | corum
# Processing Record 8 of Set 11 | muli
# Processing Record 9 of Set 11 | ust-nera
# Processing Record 10 of Set 11 | huarmey
# Processing Record 11 of Set 11 | lengshuijiang
# Processing Record 12 of Set 11 | khasan
# Processing Record 13 of Set 11 | punta de bombon
# Processing Record 14 of Set 11 | dabakala
# Processing Record 15 of Set 11 | monster
# Processing Record 16 of Set 11 | olavarria
# Processing Record 17 of Set 11 | vestmanna
# Processing Record 18 of Set 11 | sechura
# Processing Record 19 of Set 11 | itarema
# Processing Record 20 of Set 11 | gongzhuling
# Processing Record 21 of Set 11 | teluknaga
# Processing Record 22 of Set 11 | francisco sa
# Processing Record 23 of Set 11 | cayenne
# Processing Record 24 of Set 11 | quesnel
# Processing Record 25 of Set 11 | tiznit
# Processing Record 26 of Set 11 | umm kaddadah
# Processing Record 27 of Set 11 | faya
# Processing Record 28 of Set 11 | havoysund
# Processing Record 29 of Set 11 | nanortalik
# Processing Record 30 of Set 11 | golden
# Processing Record 31 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 32 of Set 11 | wollongong
# Processing Record 33 of Set 11 | sitka
# Processing Record 34 of Set 11 | oranjemund
# Processing Record 35 of Set 11 | kulhudhuffushi
# Processing Record 36 of Set 11 | sivaki
# Processing Record 37 of Set 11 | galdar
# Processing Record 38 of Set 11 | merritt island
# Processing Record 39 of Set 11 | flin flon
# Processing Record 40 of Set 11 | olinda
# Processing Record 41 of Set 11 | voh
# Processing Record 42 of Set 11 | tra vinh
# Processing Record 43 of Set 11 | mecca
# Processing Record 44 of Set 11 | norsup
# Processing Record 45 of Set 11 | quirinopolis
# Processing Record 46 of Set 11 | whangamata
# Processing Record 47 of Set 11 | erdenet
# Processing Record 48 of Set 11 | wuda
# Processing Record 49 of Set 11 | izhmorskiy
# Processing Record 50 of Set 11 | samfya
# Processing Record 1 of Set 12 | half moon bay
# Processing Record 2 of Set 12 | hay river
# Processing Record 3 of Set 12 | honiara
# Processing Record 4 of Set 12 | mokhsogollokh
# Processing Record 5 of Set 12 | hirtshals
# Processing Record 6 of Set 12 | narodychi
# Processing Record 7 of Set 12 | el carrizo
# Processing Record 8 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 12 | waycross
# Processing Record 10 of Set 12 | tommot
# Processing Record 11 of Set 12 | shakawe
# Processing Record 12 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 12 | sheridan
# Processing Record 14 of Set 12 | oshawa
# Processing Record 15 of Set 12 | mykolayivka
# Processing Record 16 of Set 12 | bonfim
# Processing Record 17 of Set 12 | kedrovyy
# Processing Record 18 of Set 12 | boende
# Processing Record 19 of Set 12 | mozelos
# Processing Record 20 of Set 12 | burns lake
# Processing Record 21 of Set 12 | kavaratti
# Processing Record 22 of Set 12 | san patricio
# Processing Record 23 of Set 12 | raudeberg
# Processing Record 24 of Set 12 | sept-iles
# Processing Record 25 of Set 12 | lunenburg
# Processing Record 26 of Set 12 | stralsund
# Processing Record 27 of Set 12 | kerouane
# Processing Record 28 of Set 12 | shelburne
# Processing Record 29 of Set 12 | verkhnetulomskiy
# Processing Record 30 of Set 12 | ludvika
# Processing Record 31 of Set 12 | hanamaki
# Processing Record 32 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 12 | wahiawa
# Processing Record 34 of Set 12 | krasnoarmeysk
# Processing Record 35 of Set 12 | pesochnoye
# Processing Record 36 of Set 12 | chernyshevskiy
# Processing Record 37 of Set 12 | omsukchan
# Processing Record 38 of Set 12 | makokou
# Processing Record 39 of Set 12 | kloulklubed
# Processing Record 40 of Set 12 | tarko-sale
# Processing Record 41 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 12 | ternate
# Processing Record 43 of Set 12 | kununurra
# Processing Record 44 of Set 12 | santa cruz
# Processing Record 45 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 46 of Set 12 | buchanan
# Processing Record 47 of Set 12 | fukue
# Processing Record 48 of Set 12 | ahipara
# Processing Record 49 of Set 12 | hovd
# Processing Record 50 of Set 12 | zhangye
# Processing Record 1 of Set 13 | kriel
# Processing Record 2 of Set 13 | gambo
# Processing Record 3 of Set 13 | mabaruma
# Processing Record 4 of Set 13 | saint-louis
# Processing Record 5 of Set 13 | eyl
# Processing Record 6 of Set 13 | mareeba
# Processing Record 7 of Set 13 | puerto madero
# Processing Record 8 of Set 13 | ordzhonikidze
# Processing Record 9 of Set 13 | isangel
# Processing Record 10 of Set 13 | sijunjung
# Processing Record 11 of Set 13 | calama
# Processing Record 12 of Set 13 | vammala
# Processing Record 13 of Set 13 | pimentel
# Processing Record 14 of Set 13 | kaduna
# Processing Record 15 of Set 13 | hanzhong
# Processing Record 16 of Set 13 | pogranichnyy
# Processing Record 17 of Set 13 | sherlovaya gora
# Processing Record 18 of Set 13 | decatur
# Processing Record 19 of Set 13 | manado
# Processing Record 20 of Set 13 | labuhan
# Processing Record 21 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 13 | riyadh
# Processing Record 23 of Set 13 | kabo
# Processing Record 24 of Set 13 | pevek
# Processing Record 25 of Set 13 | west bay
# Processing Record 26 of Set 13 | aksu
# Processing Record 27 of Set 13 | igrim
# Processing Record 28 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 29 of Set 13 | semirara
# Processing Record 30 of Set 13 | snezhnogorsk
# Processing Record 31 of Set 13 | qaqortoq
# Processing Record 32 of Set 13 | korla
# Processing Record 33 of Set 13 | kenai
# Processing Record 34 of Set 13 | manono
# Processing Record 35 of Set 13 | slave lake
# Processing Record 36 of Set 13 | hualmay
# Processing Record 37 of Set 13 | naica
# Processing Record 38 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 39 of Set 13 | walla walla
# Processing Record 40 of Set 13 | sivagiri
# Processing Record 41 of Set 13 | atar
# Processing Record 42 of Set 13 | lakhnadon
# Processing Record 43 of Set 13 | acarau
# Processing Record 44 of Set 13 | sukhumi
# Processing Record 45 of Set 13 | skjervoy
# Processing Record 46 of Set 13 | tezu
# Processing Record 47 of Set 13 | jertih
# Processing Record 48 of Set 13 | guaruja
# Processing Record 49 of Set 13 | mahajanga
# Processing Record 50 of Set 13 | kanniyakumari
# Processing Record 1 of Set 14 | kemijarvi
# Processing Record 2 of Set 14 | akdepe
# Processing Record 3 of Set 14 | porto torres
# Processing Record 4 of Set 14 | kutum
# Processing Record 5 of Set 14 | new richmond
# Processing Record 6 of Set 14 | mangrol
# Processing Record 7 of Set 14 | quelimane
# Processing Record 8 of Set 14 | tabou
# Processing Record 9 of Set 14 | kyshtovka
# Processing Record 10 of Set 14 | meulaboh
# Processing Record 11 of Set 14 | pochutla
# Processing Record 12 of Set 14 | yamethin
# Processing Record 13 of Set 14 | kiunga
# Processing Record 14 of Set 14 | teluk nibung
# Processing Record 15 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 14 | cascais
# Processing Record 17 of Set 14 | loa janan
# Processing Record 18 of Set 14 | mutis
# Processing Record 19 of Set 14 | yatou
# Processing Record 20 of Set 14 | tarime
# Processing Record 21 of Set 14 | birao
# Processing Record 22 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 14 | pozzallo
# Processing Record 24 of Set 14 | madang
# Processing Record 25 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 26 of Set 14 | bud
# Processing Record 27 of Set 14 | envira
# Processing Record 28 of Set 14 | shenjiamen
# Processing Record 29 of Set 14 | taoudenni
# Processing Record 30 of Set 14 | storforshei
# Processing Record 31 of Set 14 | general roca
# Processing Record 32 of Set 14 | shuangcheng
# Processing Record 33 of Set 14 | maldonado
# Processing Record 34 of Set 14 | muros
# Processing Record 35 of Set 14 | yar-sale
# Processing Record 36 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 14 | ruthin
# Processing Record 38 of Set 14 | klyuchi
# Processing Record 39 of Set 14 | dharchula
# Processing Record 40 of Set 14 | diamantina
# Processing Record 41 of Set 14 | los llanos de aridane
# Processing Record 42 of Set 14 | makung
# City not found. Skipping...
# Processing Record 43 of Set 14 | auki
# Processing Record 44 of Set 14 | marovoay
# Processing Record 45 of Set 14 | zhangjiakou
# Processing Record 46 of Set 14 | panjakent
# Processing Record 47 of Set 14 | san jose
# Processing Record 48 of Set 14 | manta
# Processing Record 49 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 50 of Set 14 | yellapur
# Processing Record 1 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 15 | kurilsk
# Processing Record 3 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 4 of Set 15 | baruun-urt
# Processing Record 5 of Set 15 | evensk
# Processing Record 6 of Set 15 | benguela
# Processing Record 7 of Set 15 | camocim
# Processing Record 8 of Set 15 | san quintin
# Processing Record 9 of Set 15 | ponta delgada
# Processing Record 10 of Set 15 | linhares
# Processing Record 11 of Set 15 | orlik
# Processing Record 12 of Set 15 | formosa
# Processing Record 13 of Set 15 | bavly
# Processing Record 14 of Set 15 | grand gaube
# Processing Record 15 of Set 15 | belmonte
# Processing Record 16 of Set 15 | bati
# Processing Record 17 of Set 15 | shah alam
# Processing Record 18 of Set 15 | mega
# Processing Record 19 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 15 | jalu
# Processing Record 21 of Set 15 | igarka
# Processing Record 22 of Set 15 | bouna
# Processing Record 23 of Set 15 | emerald
# Processing Record 24 of Set 15 | kindu
# Processing Record 25 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 15 | takhtamygda
# Processing Record 27 of Set 15 | talaya
# Processing Record 28 of Set 15 | liepaja
# Processing Record 29 of Set 15 | bambanglipuro
# Processing Record 30 of Set 15 | akyab
# Processing Record 31 of Set 15 | turukhansk
# Processing Record 32 of Set 15 | malakal
# Processing Record 33 of Set 15 | zemio
# Processing Record 34 of Set 15 | thunder bay
# Processing Record 35 of Set 15 | olden
# Processing Record 36 of Set 15 | apt
# Processing Record 37 of Set 15 | kodinar
# Processing Record 38 of Set 15 | ulladulla
# Processing Record 39 of Set 15 | lavrentiya
# Processing Record 40 of Set 15 | nazarovo
# Processing Record 41 of Set 15 | chiredzi
# Processing Record 42 of Set 15 | marsh harbour
# Processing Record 43 of Set 15 | sfantu gheorghe

# %%
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Loading Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Data Loading Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     78.26        72          76
# 1    Kaitangata      NZ -46.2817  169.8464     53.92        81          16
# 2          Poum      NC -20.2333  164.0167     81.57        78          94
# 3     Carnarvon      AU -24.8667  113.6333     77.07        88           3
# 4  Kudahuvadhoo      MV   2.6708   72.8944     81.55        78         100
#
#    Wind Speed Current Description
# 0       12.10          light rain
# 1        2.86          few clouds
# 2       13.53     overcast clouds
# 3        5.75           clear sky
# 4       10.83     overcast clouds

# %%
#Recall that to reorder the columns, we assign a variable to an array of the columns in the order 
#we want them to appear:

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

#Then, we assign a new or the same DataFrame with new column order:

city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database/weatherpy_database2.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
