# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Add the code that generates the latitudes and longitudes, but first, they need to be stored so that we can access them later. 
#Since we are creating arrays of latitudes and longitudes, we'll declare each array as a variable.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 628

# %%
#Some of this code should look familiar, but let's break it down:
#We create a cities list to store city names.
#We iterate through the coordinates, as in our practice, 
#and retrieve the nearest city using the latitude and longitude pair.
#We add a decision statement with the logical operator not in to determine 
#whether the found city is already in the cities list. If not, then we'll use the append() function to add it. 
#We are doing this because among the 1,500 latitudes and longitudes, there might be duplicates, 
#which will retrieve duplicate cities, and we want to be sure we capture only the unique cities.

# %%
#Now that we know how to get all the weather data from a JSON response, 
#we can iterate through our cities list and retrieve the data from each city.

#We will need to do the following:

#Import our dependencies and initialize counters and an empty list that will hold the weather data.
#Loop through the cities list.
#Group the cities in sets of 50 to log the process as we find the weather data for each city.
#Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
#Build the city_url or endpoint for each city.
#Log the URL and the record and set numbers.
#Make an API request for each city.
#Parse the JSON weather data for the following:
#City, country, and date
#Latitude and longitude
#Maximum temperature
#Humidity
#Cloudiness
#Wind speed
#Add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %%
city_data = []

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#In the code block, we have initialized the counters at 1 because we want the first iteration of the logging 
#for each recorded response and the set to start at 1.
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#Next, we need to iterate through our list of cities and begin building the URL for each city, 
#while grouping our records in sets of 50. To do this, use for i in range(len(cities)) 
#and the index to tell us when we get to 50.

# Loop through all the cities in our list.
#Every time we want to reference the city in our code, we need to use the indexing on the cities list. 
#Unfortunately, this will cause programming errors when we are building the city_url 
#because it adds the index, not the city name, to the city_url. To fix this issue, 
#we need to create another for loop to get the city from the cities list.
#------------------------------------------------------------------------------
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" 

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
#Once we get to 50, we tell the program to pause for 60 seconds using the time.sleep(60) command. 
#The OpenWeatherMap API only allows 60 calls for per minute on their free tier, 
#so pausing our program for one minute after each set of 50 will prevent time-out errors. 
        time.sleep(60)
#We can also retrieve the city from the cities list and add it to the city_url by using indexing,    
    city_url = url + "&q=" + cities[i]
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Processing Record 1 of Set 1 | bhaderwah
# Processing Record 2 of Set 1 | maholi
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | taolanaro
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | meulaboh
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | nizhneyansk
# Processing Record 11 of Set 1 | san cristobal
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | nara
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | harper
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | ballina
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | zyryanka
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | san buenaventura
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | khani
# Processing Record 33 of Set 1 | miramar
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | bandarbeyla
# Processing Record 37 of Set 1 | norman wells
# Processing Record 38 of Set 1 | hokitika
# Processing Record 39 of Set 1 | hasaki
# Processing Record 40 of Set 1 | mizusawa
# Processing Record 41 of Set 1 | ulladulla
# Processing Record 42 of Set 1 | bolungarvik
# Processing Record 43 of Set 1 | hervey bay
# Processing Record 44 of Set 1 | kirtipur
# Processing Record 45 of Set 1 | cliza
# Processing Record 46 of Set 1 | adrar
# Processing Record 47 of Set 1 | haines junction
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | zhanatas
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | mount gambier
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | leh
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | vila franca do campo
# Processing Record 8 of Set 2 | sentyabrskiy
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | saint-francois
# Processing Record 11 of Set 2 | port hardy
# Processing Record 12 of Set 2 | el seibo
# Processing Record 13 of Set 2 | coquimbo
# Processing Record 14 of Set 2 | praia da vitoria
# Processing Record 15 of Set 2 | chanderi
# Processing Record 16 of Set 2 | bababe
# Processing Record 17 of Set 2 | barentsburg
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | ariquemes
# Processing Record 21 of Set 2 | vestmannaeyjar
# Processing Record 22 of Set 2 | severo-kurilsk
# Processing Record 23 of Set 2 | khandbari
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | salalah
# Processing Record 26 of Set 2 | mae sot
# Processing Record 27 of Set 2 | russell
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | yeletskiy
# Processing Record 30 of Set 2 | ust-nera
# Processing Record 31 of Set 2 | mys shmidta
# Processing Record 32 of Set 2 | belushya guba
# Processing Record 33 of Set 2 | imeni poliny osipenko
# Processing Record 34 of Set 2 | providencia
# Processing Record 35 of Set 2 | kikwit
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | caravelas
# Processing Record 38 of Set 2 | vaitupu
# Processing Record 39 of Set 2 | zyryanovsk
# Processing Record 40 of Set 2 | miraflores
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | dingle
# Processing Record 43 of Set 2 | airai
# Processing Record 44 of Set 2 | isla vista
# Processing Record 45 of Set 2 | angoche
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | puerto madryn
# Processing Record 48 of Set 2 | wuwei
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 50 of Set 2 | mar del plata
# Processing Record 1 of Set 3 | inirida
# Processing Record 2 of Set 3 | coahuayana
# Processing Record 3 of Set 3 | ust-kamchatsk
# Processing Record 4 of Set 3 | weligama
# Processing Record 5 of Set 3 | kavieng
# Processing Record 6 of Set 3 | madras
# Processing Record 7 of Set 3 | verkhniy mamon
# Processing Record 8 of Set 3 | isangel
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | lata
# Processing Record 12 of Set 3 | thompson
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | dalarik
# Processing Record 16 of Set 3 | buchanan
# Processing Record 17 of Set 3 | lannion
# Processing Record 18 of Set 3 | albany
# Processing Record 19 of Set 3 | celano
# Processing Record 20 of Set 3 | victoria
# Processing Record 21 of Set 3 | sorvag
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | mwinilunga
# Processing Record 24 of Set 3 | ranong
# Processing Record 25 of Set 3 | barrow
# Processing Record 26 of Set 3 | atherton
# Processing Record 27 of Set 3 | arrah
# Processing Record 28 of Set 3 | khandyga
# Processing Record 29 of Set 3 | illoqqortoormiut
# Processing Record 30 of Set 3 | dmytrivka
# Processing Record 31 of Set 3 | kouango
# Processing Record 32 of Set 3 | samarai
# Processing Record 33 of Set 3 | acapulco
# Processing Record 34 of Set 3 | kerrobert
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | jacareacanga
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | penzance
# Processing Record 39 of Set 3 | gushikawa
# Processing Record 40 of Set 3 | khatanga
# Processing Record 41 of Set 3 | hanzhong
# Processing Record 42 of Set 3 | bengkulu
# Processing Record 43 of Set 3 | nanortalik
# Processing Record 44 of Set 3 | carnarvon
# Processing Record 45 of Set 3 | biak
# Processing Record 46 of Set 3 | seoul
# Processing Record 47 of Set 3 | aketi
# Processing Record 48 of Set 3 | te anau
# Processing Record 49 of Set 3 | sinkat
# Processing Record 50 of Set 3 | belmonte
# Processing Record 1 of Set 4 | mtimbira
# Processing Record 2 of Set 4 | port hawkesbury
# Processing Record 3 of Set 4 | umm lajj
# Processing Record 4 of Set 4 | pisco
# Processing Record 5 of Set 4 | tazovskiy
# Processing Record 6 of Set 4 | dhuburi
# Processing Record 7 of Set 4 | santa vitoria do palmar
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | pochutla
# Processing Record 10 of Set 4 | pathein
# Processing Record 11 of Set 4 | challapata
# Processing Record 12 of Set 4 | faanui
# Processing Record 13 of Set 4 | prince george
# Processing Record 14 of Set 4 | pinerolo
# Processing Record 15 of Set 4 | tumannyy
# Processing Record 16 of Set 4 | vardo
# Processing Record 17 of Set 4 | pastavy
# Processing Record 18 of Set 4 | ola
# Processing Record 19 of Set 4 | luderitz
# Processing Record 20 of Set 4 | kampene
# Processing Record 21 of Set 4 | lebu
# Processing Record 22 of Set 4 | bredasdorp
# Processing Record 23 of Set 4 | fortuna
# Processing Record 24 of Set 4 | arcachon
# Processing Record 25 of Set 4 | nakhon phanom
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | alice springs
# Processing Record 28 of Set 4 | marechal candido rondon
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | nenjiang
# Processing Record 31 of Set 4 | krasnokamensk
# Processing Record 32 of Set 4 | provideniya
# Processing Record 33 of Set 4 | asaba
# Processing Record 34 of Set 4 | souillac
# Processing Record 35 of Set 4 | kahului
# Processing Record 36 of Set 4 | qiqihar
# Processing Record 37 of Set 4 | hurghada
# Processing Record 38 of Set 4 | bereda
# Processing Record 39 of Set 4 | mujiayingzi
# Processing Record 40 of Set 4 | zhangjiakou
# Processing Record 41 of Set 4 | pangai
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | mazagao
# Processing Record 44 of Set 4 | egvekinot
# Processing Record 45 of Set 4 | saleaula
# Processing Record 46 of Set 4 | butaritari
# Processing Record 47 of Set 4 | sawai madhopur
# Processing Record 48 of Set 4 | udachnyy
# Processing Record 49 of Set 4 | sorland
# Processing Record 50 of Set 4 | luanda
# Processing Record 1 of Set 5 | karratha
# Processing Record 2 of Set 5 | turkan
# Processing Record 3 of Set 5 | sao jose da coroa grande
# Processing Record 4 of Set 5 | cayenne
# Processing Record 5 of Set 5 | mitsamiouli
# Processing Record 6 of Set 5 | sigayevo
# Processing Record 7 of Set 5 | nagua
# Processing Record 8 of Set 5 | bonthe
# Processing Record 9 of Set 5 | qaanaaq
# Processing Record 10 of Set 5 | simplicio mendes
# Processing Record 11 of Set 5 | guerrero negro
# Processing Record 12 of Set 5 | tomatlan
# Processing Record 13 of Set 5 | coffs harbour
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | antofagasta
# Processing Record 16 of Set 5 | constitucion
# Processing Record 17 of Set 5 | amderma
# Processing Record 18 of Set 5 | okhotsk
# Processing Record 19 of Set 5 | hun
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | longyearbyen
# Processing Record 22 of Set 5 | samusu
# Processing Record 23 of Set 5 | kawana waters
# Processing Record 24 of Set 5 | kathu
# Processing Record 25 of Set 5 | isparta
# Processing Record 26 of Set 5 | husainabad
# Processing Record 27 of Set 5 | cap-aux-meules
# Processing Record 28 of Set 5 | afrikanda
# Processing Record 29 of Set 5 | saint-pierre
# Processing Record 30 of Set 5 | ancud
# Processing Record 31 of Set 5 | palabuhanratu
# Processing Record 32 of Set 5 | road town
# Processing Record 33 of Set 5 | huanren
# Processing Record 34 of Set 5 | kabale
# Processing Record 35 of Set 5 | spornoye
# Processing Record 36 of Set 5 | neuquen
# Processing Record 37 of Set 5 | lipari
# Processing Record 38 of Set 5 | moose factory
# Processing Record 39 of Set 5 | bedesa
# Processing Record 40 of Set 5 | mehran
# Processing Record 41 of Set 5 | mabaruma
# Processing Record 42 of Set 5 | birin
# Processing Record 43 of Set 5 | nelson bay
# Processing Record 44 of Set 5 | kirillov
# Processing Record 45 of Set 5 | formosa
# Processing Record 46 of Set 5 | ugoofaaru
# Processing Record 47 of Set 5 | kologriv
# Processing Record 48 of Set 5 | tete
# Processing Record 49 of Set 5 | lasa
# Processing Record 50 of Set 5 | kaitangata
# Processing Record 1 of Set 6 | cristalina
# Processing Record 2 of Set 6 | san quintin
# Processing Record 3 of Set 6 | belaya gora
# Processing Record 4 of Set 6 | hai duong
# Processing Record 5 of Set 6 | sao joao da barra
# Processing Record 6 of Set 6 | quatre cocos
# Processing Record 7 of Set 6 | san matias
# Processing Record 8 of Set 6 | yerbogachen
# Processing Record 9 of Set 6 | tsihombe
# Processing Record 10 of Set 6 | apiai
# Processing Record 11 of Set 6 | fort nelson
# Processing Record 12 of Set 6 | louisbourg
# Processing Record 13 of Set 6 | vao
# Processing Record 14 of Set 6 | oranjemund
# Processing Record 15 of Set 6 | awjilah
# Processing Record 16 of Set 6 | edd
# Processing Record 17 of Set 6 | diamantino
# Processing Record 18 of Set 6 | chuy
# Processing Record 19 of Set 6 | kudahuvadhoo
# Processing Record 20 of Set 6 | walvis bay
# Processing Record 21 of Set 6 | mahabaleshwar
# Processing Record 22 of Set 6 | ust-kuyga
# Processing Record 23 of Set 6 | abu kamal
# Processing Record 24 of Set 6 | hambantota
# Processing Record 25 of Set 6 | trstenik
# Processing Record 26 of Set 6 | uromi
# Processing Record 27 of Set 6 | odessa
# Processing Record 28 of Set 6 | sangar
# Processing Record 29 of Set 6 | liesveld
# Processing Record 30 of Set 6 | naryan-mar
# Processing Record 31 of Set 6 | iqaluit
# Processing Record 32 of Set 6 | hualmay
# Processing Record 33 of Set 6 | tacub
# Processing Record 34 of Set 6 | valle de allende
# Processing Record 35 of Set 6 | lichuan
# Processing Record 36 of Set 6 | palmer
# Processing Record 37 of Set 6 | balkanabat
# Processing Record 38 of Set 6 | tamiahua
# Processing Record 39 of Set 6 | kurumkan
# Processing Record 40 of Set 6 | ibra
# Processing Record 41 of Set 6 | ahipara
# Processing Record 42 of Set 6 | flin flon
# Processing Record 43 of Set 6 | kodiak
# Processing Record 44 of Set 6 | waipawa
# Processing Record 45 of Set 6 | cururupu
# Processing Record 46 of Set 6 | poum
# Processing Record 47 of Set 6 | saldanha
# Processing Record 48 of Set 6 | ilovlya
# Processing Record 49 of Set 6 | san carlos de bariloche
# Processing Record 50 of Set 6 | banjarmasin
# Processing Record 1 of Set 7 | kaihua
# Processing Record 2 of Set 7 | steamboat springs
# Processing Record 3 of Set 7 | trapani
# Processing Record 4 of Set 7 | warqla
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | merauke
# Processing Record 7 of Set 7 | sangin
# Processing Record 8 of Set 7 | rypefjord
# Processing Record 9 of Set 7 | karoi
# Processing Record 10 of Set 7 | lolua
# Processing Record 11 of Set 7 | shelburne
# Processing Record 12 of Set 7 | chagda
# Processing Record 13 of Set 7 | kadykchan
# Processing Record 14 of Set 7 | kruisfontein
# Processing Record 15 of Set 7 | gull lake
# Processing Record 16 of Set 7 | mezhdurechensk
# Processing Record 17 of Set 7 | baghdad
# Processing Record 18 of Set 7 | lujan
# Processing Record 19 of Set 7 | progreso
# Processing Record 20 of Set 7 | along
# Processing Record 21 of Set 7 | evensk
# Processing Record 22 of Set 7 | tautira
# Processing Record 23 of Set 7 | yialos
# Processing Record 24 of Set 7 | kardla
# Processing Record 25 of Set 7 | axtla
# Processing Record 26 of Set 7 | belyy yar
# Processing Record 27 of Set 7 | yulin
# Processing Record 28 of Set 7 | mana
# Processing Record 29 of Set 7 | comodoro rivadavia
# Processing Record 30 of Set 7 | shenjiamen
# Processing Record 31 of Set 7 | namibe
# Processing Record 32 of Set 7 | traralgon
# Processing Record 33 of Set 7 | aswan
# Processing Record 34 of Set 7 | zhigansk
# Processing Record 35 of Set 7 | nikel
# Processing Record 36 of Set 7 | el cope
# Processing Record 37 of Set 7 | mangai
# Processing Record 38 of Set 7 | atasu
# Processing Record 39 of Set 7 | pangody
# Processing Record 40 of Set 7 | esperance
# Processing Record 41 of Set 7 | nome
# Processing Record 42 of Set 7 | windhoek
# Processing Record 43 of Set 7 | estrela
# Processing Record 44 of Set 7 | sinnamary
# Processing Record 45 of Set 7 | mantua
# Processing Record 46 of Set 7 | axim
# Processing Record 47 of Set 7 | makat
# Processing Record 48 of Set 7 | zharkent
# Processing Record 49 of Set 7 | buzdyak
# Processing Record 50 of Set 7 | bykovo
# Processing Record 1 of Set 8 | ust-omchug
# Processing Record 2 of Set 8 | cordoba
# Processing Record 3 of Set 8 | elban
# Processing Record 4 of Set 8 | kargapolye
# Processing Record 5 of Set 8 | encinitas
# Processing Record 6 of Set 8 | vestmanna
# Processing Record 7 of Set 8 | kununurra
# Processing Record 8 of Set 8 | naze
# Processing Record 9 of Set 8 | sehithwa
# Processing Record 10 of Set 8 | berkovica
# Processing Record 11 of Set 8 | broken hill
# Processing Record 12 of Set 8 | saryshagan
# Processing Record 13 of Set 8 | bullhead city
# Processing Record 14 of Set 8 | sao filipe
# Processing Record 15 of Set 8 | pozo colorado
# Processing Record 16 of Set 8 | iberia
# Processing Record 17 of Set 8 | dicabisagan
# Processing Record 18 of Set 8 | san ramon
# Processing Record 19 of Set 8 | bozeman
# Processing Record 20 of Set 8 | colares
# Processing Record 21 of Set 8 | general roca
# Processing Record 22 of Set 8 | pangnirtung
# Processing Record 23 of Set 8 | tevaitoa
# Processing Record 24 of Set 8 | karamken
# Processing Record 25 of Set 8 | himora
# Processing Record 26 of Set 8 | mogadishu
# Processing Record 27 of Set 8 | cherskiy
# Processing Record 28 of Set 8 | lebyazhye
# Processing Record 29 of Set 8 | emerald
# Processing Record 30 of Set 8 | katsuura
# Processing Record 31 of Set 8 | abhaynagar
# Processing Record 32 of Set 8 | maniitsoq
# Processing Record 33 of Set 8 | opuwo
# Processing Record 34 of Set 8 | acarau
# Processing Record 35 of Set 8 | montepuez
# Processing Record 36 of Set 8 | vila velha
# Processing Record 37 of Set 8 | mlonggo
# Processing Record 38 of Set 8 | exeter
# Processing Record 39 of Set 8 | amahai
# Processing Record 40 of Set 8 | los llanos de aridane
# Processing Record 41 of Set 8 | sterling
# Processing Record 42 of Set 8 | san isidro
# Processing Record 43 of Set 8 | marawi
# Processing Record 44 of Set 8 | bouca
# Processing Record 45 of Set 8 | nantucket
# Processing Record 46 of Set 8 | dunedin
# Processing Record 47 of Set 8 | sur
# Processing Record 48 of Set 8 | george
# Processing Record 49 of Set 8 | melton
# Processing Record 50 of Set 8 | narsaq
# Processing Record 1 of Set 9 | burica
# Processing Record 2 of Set 9 | west plains
# Processing Record 3 of Set 9 | nouadhibou
# Processing Record 4 of Set 9 | flinders
# Processing Record 5 of Set 9 | chulym
# Processing Record 6 of Set 9 | cedar city
# Processing Record 7 of Set 9 | sahawar
# Processing Record 8 of Set 9 | teahupoo
# Processing Record 9 of Set 9 | touros
# Processing Record 10 of Set 9 | champerico
# Processing Record 11 of Set 9 | chhabra
# Processing Record 12 of Set 9 | ostrovnoy
# Processing Record 13 of Set 9 | helena
# Processing Record 14 of Set 9 | ilulissat
# Processing Record 15 of Set 9 | lago da pedra
# Processing Record 16 of Set 9 | sosva
# Processing Record 17 of Set 9 | goderich
# Processing Record 18 of Set 9 | masuguru
# Processing Record 19 of Set 9 | kodinsk
# Processing Record 20 of Set 9 | dolny kubin
# Processing Record 21 of Set 9 | lorengau
# Processing Record 22 of Set 9 | coppell
# Processing Record 23 of Set 9 | skelleftea
# Processing Record 24 of Set 9 | altus
# Processing Record 25 of Set 9 | chimoio
# Processing Record 26 of Set 9 | bonfim
# Processing Record 27 of Set 9 | gdynia
# Processing Record 28 of Set 9 | skalistyy
# Processing Record 29 of Set 9 | mnogovershinnyy
# Processing Record 30 of Set 9 | fare
# Processing Record 31 of Set 9 | ambanja
# Processing Record 32 of Set 9 | balikpapan
# Processing Record 33 of Set 9 | salinopolis
# Processing Record 34 of Set 9 | laizhou
# Processing Record 35 of Set 9 | jining
# Processing Record 36 of Set 9 | ialibu
# Processing Record 37 of Set 9 | yaransk
# Processing Record 38 of Set 9 | berlevag
# Processing Record 39 of Set 9 | les herbiers
# Processing Record 40 of Set 9 | codrington
# Processing Record 41 of Set 9 | mount isa
# Processing Record 42 of Set 9 | mattru
# Processing Record 43 of Set 9 | rock sound
# Processing Record 44 of Set 9 | senador jose porfirio
# Processing Record 45 of Set 9 | calvinia
# Processing Record 46 of Set 9 | beyneu
# Processing Record 47 of Set 9 | rabaul
# Processing Record 48 of Set 9 | fort morgan
# Processing Record 49 of Set 9 | shimoda
# Processing Record 50 of Set 9 | novikovo
# Processing Record 1 of Set 10 | sitka
# Processing Record 2 of Set 10 | purpe
# Processing Record 3 of Set 10 | hailar
# Processing Record 4 of Set 10 | grants
# Processing Record 5 of Set 10 | umzimvubu
# Processing Record 6 of Set 10 | megion
# Processing Record 7 of Set 10 | meyungs
# Processing Record 8 of Set 10 | ajdabiya
# Processing Record 9 of Set 10 | hami
# Processing Record 10 of Set 10 | prince rupert
# Processing Record 11 of Set 10 | jalu
# Processing Record 12 of Set 10 | honningsvag
# Processing Record 13 of Set 10 | makhachkala
# Processing Record 14 of Set 10 | henties bay
# Processing Record 15 of Set 10 | raga
# Processing Record 16 of Set 10 | chateauroux
# Processing Record 17 of Set 10 | trelew
# Processing Record 18 of Set 10 | taltal
# Processing Record 19 of Set 10 | high level
# Processing Record 20 of Set 10 | dudinka
# Processing Record 21 of Set 10 | taburi
# Processing Record 22 of Set 10 | bolitoc
# Processing Record 23 of Set 10 | yumen
# Processing Record 24 of Set 10 | buariki
# Processing Record 25 of Set 10 | clermont
# Processing Record 26 of Set 10 | beira
# Processing Record 27 of Set 10 | port macquarie
# Processing Record 28 of Set 10 | chadan
# Processing Record 29 of Set 10 | dzaoudzi
# Processing Record 30 of Set 10 | cazaje
# Processing Record 31 of Set 10 | grand river south east
# Processing Record 32 of Set 10 | boa vista
# Processing Record 33 of Set 10 | warwick
# Processing Record 34 of Set 10 | dir
# Processing Record 35 of Set 10 | bani walid
# Processing Record 36 of Set 10 | dawei
# Processing Record 37 of Set 10 | nong han
# Processing Record 38 of Set 10 | padang
# Processing Record 39 of Set 10 | necochea
# Processing Record 40 of Set 10 | kokopo
# Processing Record 41 of Set 10 | istra
# Processing Record 42 of Set 10 | agva
# Processing Record 43 of Set 10 | tateyama
# Processing Record 44 of Set 10 | przasnysz
# Processing Record 45 of Set 10 | amazar
# Processing Record 46 of Set 10 | yantal
# Processing Record 47 of Set 10 | rexburg
# Processing Record 48 of Set 10 | lavrentiya
# Processing Record 49 of Set 10 | richards bay
# Processing Record 50 of Set 10 | koutsouras
# Processing Record 1 of Set 11 | morondava
# Processing Record 2 of Set 11 | tabory
# Processing Record 3 of Set 11 | dalvik
# Processing Record 4 of Set 11 | karauzyak
# Processing Record 5 of Set 11 | lakes entrance
# Processing Record 6 of Set 11 | kropotkin
# Processing Record 7 of Set 11 | miyako
# Processing Record 8 of Set 11 | aleksandrovskiy zavod
# Processing Record 9 of Set 11 | plettenberg bay
# Processing Record 10 of Set 11 | bagdarin
# Processing Record 11 of Set 11 | riyadh
# Processing Record 12 of Set 11 | chipinge
# Processing Record 13 of Set 11 | soure
# Processing Record 14 of Set 11 | ngukurr
# Processing Record 15 of Set 11 | husavik
# Processing Record 16 of Set 11 | lanzhou
# Processing Record 17 of Set 11 | ughelli
# Processing Record 18 of Set 11 | muros
# Processing Record 19 of Set 11 | wanaka
# Processing Record 20 of Set 11 | banda aceh
# Processing Record 21 of Set 11 | concepcion
# Processing Record 22 of Set 11 | albanel
# Processing Record 23 of Set 11 | ballybofey
# Processing Record 24 of Set 11 | terra santa
# Processing Record 25 of Set 11 | chitral
# Processing Record 26 of Set 11 | nishihara
# Processing Record 27 of Set 11 | havelock
# Processing Record 28 of Set 11 | santa cruz de tenerife
# Processing Record 29 of Set 11 | sendafa
# Processing Record 30 of Set 11 | titel
# Processing Record 31 of Set 11 | ramon castilla
# Processing Record 32 of Set 11 | port blair
# Processing Record 33 of Set 11 | lagoa
# Processing Record 34 of Set 11 | kalmunai
# Processing Record 35 of Set 11 | mecca
# Processing Record 36 of Set 11 | itoman
# Processing Record 37 of Set 11 | lobbes
# Processing Record 38 of Set 11 | mitchell
# Processing Record 39 of Set 11 | lingao
# Processing Record 40 of Set 11 | linares
# Processing Record 41 of Set 11 | luzhany
# Processing Record 42 of Set 11 | labuhan
# Processing Record 43 of Set 11 | mount pleasant
# Processing Record 44 of Set 11 | carutapera
# Processing Record 45 of Set 11 | creel
# Processing Record 46 of Set 11 | mogok
# Processing Record 47 of Set 11 | languyan
# Processing Record 48 of Set 11 | santa maria del oro
# Processing Record 49 of Set 11 | fairbanks
# Processing Record 50 of Set 11 | ngunguru
# Processing Record 1 of Set 12 | kenora
# Processing Record 2 of Set 12 | great falls
# Processing Record 3 of Set 12 | hamilton
# Processing Record 4 of Set 12 | traipu
# Processing Record 5 of Set 12 | kyabe
# Processing Record 6 of Set 12 | nabire
# Processing Record 7 of Set 12 | dalton
# Processing Record 8 of Set 12 | benguela
# Processing Record 9 of Set 12 | bolobo
# Processing Record 10 of Set 12 | norden
# Processing Record 11 of Set 12 | rafai
# Processing Record 12 of Set 12 | bollnas
# Processing Record 13 of Set 12 | portland
# Processing Record 14 of Set 12 | itaituba
# Processing Record 15 of Set 12 | sola
# Processing Record 16 of Set 12 | mampong
# Processing Record 17 of Set 12 | mariel
# Processing Record 18 of Set 12 | kargil
# Processing Record 19 of Set 12 | jutai
# Processing Record 20 of Set 12 | katobu
# Processing Record 21 of Set 12 | grand gaube
# Processing Record 22 of Set 12 | manhattan
# Processing Record 23 of Set 12 | carbonera
# Processing Record 24 of Set 12 | quang ngai
# Processing Record 25 of Set 12 | energetik
# Processing Record 26 of Set 12 | boende
# Processing Record 27 of Set 12 | armacao dos buzios
# Processing Record 28 of Set 12 | kirakira
# Processing Record 29 of Set 12 | gospic
# Processing Record 30 of Set 12 | peace river
# Processing Record 31 of Set 12 | san lawrenz
# Processing Record 32 of Set 12 | monrovia
# Processing Record 33 of Set 12 | tlyarota
# Processing Record 34 of Set 12 | olafsvik
# Processing Record 35 of Set 12 | sabang
# Processing Record 36 of Set 12 | verkhoyansk
# Processing Record 37 of Set 12 | ibanda
# Processing Record 38 of Set 12 | tahoua
# Processing Record 39 of Set 12 | ewa beach
# Processing Record 40 of Set 12 | kanye
# Processing Record 41 of Set 12 | gorokhovets
# Processing Record 42 of Set 12 | hay river
# Processing Record 43 of Set 12 | talnakh
# Processing Record 44 of Set 12 | tual
# Processing Record 45 of Set 12 | san jeronimo
# Processing Record 46 of Set 12 | lauingen
# Processing Record 47 of Set 12 | bara
# Processing Record 48 of Set 12 | chicla
# Processing Record 49 of Set 12 | nalut
# Processing Record 50 of Set 12 | labutta
# Processing Record 1 of Set 13 | tetiyiv
# Processing Record 2 of Set 13 | ust-uda
# Processing Record 3 of Set 13 | ambulu
# Processing Record 4 of Set 13 | alanya
# Processing Record 5 of Set 13 | toliary
# Processing Record 6 of Set 13 | wanning
# Processing Record 7 of Set 13 | sobolevo
# Processing Record 8 of Set 13 | mbandaka
# Processing Record 9 of Set 13 | greenville
# Processing Record 10 of Set 13 | omboue
# Processing Record 11 of Set 13 | zverinogolovskoye
# Processing Record 12 of Set 13 | kawalu
# Processing Record 13 of Set 13 | karasburg
# Processing Record 14 of Set 13 | poltavka
# Processing Record 15 of Set 13 | pavelets
# Processing Record 16 of Set 13 | wattegama
# Processing Record 17 of Set 13 | moulins
# Processing Record 18 of Set 13 | missoula
# Processing Record 19 of Set 13 | panguma
# Processing Record 20 of Set 13 | qurunbaliyah
# Processing Record 21 of Set 13 | maumere
# Processing Record 22 of Set 13 | coolum beach
# Processing Record 23 of Set 13 | cottbus
# Processing Record 24 of Set 13 | northam
# Processing Record 25 of Set 13 | mehamn
# Processing Record 26 of Set 13 | rabo de peixe
# Processing Record 27 of Set 13 | adre
# Processing Record 28 of Set 13 | klaksvik

# %%
# Run an API request for each of the cities.Module 6.2.6
try:
        # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
        # Parse out the needed data.
    city_lat = city_weather["coord"]["lat"]
    city_lng = city_weather["coord"]["lon"]
    city_max_temp = city_weather["main"]["temp_max"]
    city_humidity = city_weather["main"]["humidity"]
    city_clouds = city_weather["clouds"]["all"]
    city_wind = city_weather["wind"]["speed"]
    city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
    city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
    city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
    print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#6.2.7 Creating a dataframe of City weather

# %%
#Recall that we can convert a list of dictionaries to a Pandas DataFrame using 
#df = pd.DataFrame(list with dictionaries).
import pandas as pd

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
#Dataframe in 6.3.1 is not showing up
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Recall that to reorder the columns, we assign a variable to an array of the columns in the order 
#we want them to appear:

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

#Then, we assign a new or the same DataFrame with new column order:

city_data_df = city_data_df[new_column_order]
city_data_df

# %%
#The last line in the code block will export the DataFrame to a CSV file, with the index label (or column A) 
#header as "City_ID." If we ever need to export the CSV file to a DataFrame, that header will be present in the DataFrame.

# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

#We've completed our tasks for making API calls, parsing the response, and collecting the data for our project

# %%
#gitignor in module 6.2.7

# %%
#Getting Data for Plotting

# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
#the code to create a scatter plot for latitude versus humidity. 
plt.scatter(lats, humidity, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
#refactor the code for our scatter plots by changing the y-axis variable to "cloudiness," 
#the title to "Cloudiness (%)," and the y-axis label to "Cloudiness (%)."

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
#Let's repurpose the code we have been using and change the y-axis variable to "wind speed," 
#the title to "Wind Speed," and the y-axis label to "Wind Speed (mph)."

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
